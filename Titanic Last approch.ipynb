# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train = pd.read_csv('train.csv')

# %%
test = pd.read_csv('test.csv')

# %%
c_train = train.copy()
c_train['S'] = 1

# %%
c_test = test.copy()
c_test['S'] = 0

# %%
df = pd.concat([c_train,c_test],axis=0, ignore_index=True)

# %%
pd.set_option('display.max_columns',81)
pd.set_option('display.max_rows',81)

# %%
df
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1       0.0       3
# 1               2       1.0       1
# 2               3       1.0       3
# 3               4       1.0       1
# 4               5       0.0       3
# ...           ...       ...     ...
# 1304         1305       NaN       3
# 1305         1306       NaN       1
# 1306         1307       NaN       3
# 1307         1308       NaN       3
# 1308         1309       NaN       3
#
#                                                    Name     Sex   Age  SibSp  \
# 0                               Braund, Mr. Owen Harris    male  22.0      1
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss. Laina  female  26.0      0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                              Allen, Mr. William Henry    male  35.0      0
# ...

# %%
df_numeric = df.select_dtypes(exclude='object')

# %%
df_numeric
# Out:
#       PassengerId  Survived  Pclass   Age  SibSp  Parch      Fare  S
# 0               1       0.0       3  22.0      1      0    7.2500  1
# 1               2       1.0       1  38.0      1      0   71.2833  1
# 2               3       1.0       3  26.0      0      0    7.9250  1
# 3               4       1.0       1  35.0      1      0   53.1000  1
# 4               5       0.0       3  35.0      0      0    8.0500  1
# ...           ...       ...     ...   ...    ...    ...       ... ..
# 1304         1305       NaN       3   NaN      0      0    8.0500  0
# 1305         1306       NaN       1  39.0      0      0  108.9000  0
# 1306         1307       NaN       3  38.5      0      0    7.2500  0
# 1307         1308       NaN       3   NaN      0      0    8.0500  0
# 1308         1309       NaN       3   NaN      1      1   22.3583  0
#
# [1309 rows x 8 columns]

# %%
df_object = df.select_dtypes(include='object')

# %%
df.isna().sum()
# Out:
# PassengerId       0
# Survived        418
# Pclass            0
# Name              0
# Sex               0
# Age             263
# SibSp             0
# Parch             0
# Ticket            0
# Fare              1
# Cabin          1014
# Embarked          2
# S                 0
# dtype: int64

# %%
df[['Name','Sex','Age','SibSp','Parch']].head(80)
# Out:
#                                                  Name     Sex    Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.00      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.00      1
# 2                              Heikkinen, Miss. Laina  female  26.00      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.00      1
# 4                            Allen, Mr. William Henry    male  35.00      0
# 5                                    Moran, Mr. James    male    NaN      0
# 6                             McCarthy, Mr. Timothy J    male  54.00      0
# 7                      Palsson, Master. Gosta Leonard    male   2.00      3
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.00      0
# 9                 Nasser, Mrs. Nicholas (Adele Achem)  female  14.00      1
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.00      1
# ...

# %%
df[['surname','Last']] = df['Name'].str.split(',', expand=True)

# %%
df[['pre','name1','ex']] =df['Last'].str.split('.', expand=True)

# %%
df
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1       0.0       3
# 1               2       1.0       1
# 2               3       1.0       3
# 3               4       1.0       1
# 4               5       0.0       3
# ...           ...       ...     ...
# 1304         1305       NaN       3
# 1305         1306       NaN       1
# 1306         1307       NaN       3
# 1307         1308       NaN       3
# 1308         1309       NaN       3
#
#                                                    Name     Sex   Age  SibSp  \
# 0                               Braund, Mr. Owen Harris    male  22.0      1
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss. Laina  female  26.0      0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                              Allen, Mr. William Henry    male  35.0      0
# ...

# %%
df.drop('Last',axis=1,inplace=True)

# %%
df.drop('ex', axis=1,inplace=True)

# %%
df['pre'].value_counts()
# Out:
#  Mr              757
#  Miss            260
#  Mrs             197
#  Master           61
#  Dr                8
#  Rev               8
#  Col               4
#  Major             2
#  Ms                2
#  Mlle              2
#  Jonkheer          1
#  Don               1
#  the Countess      1
#  Lady              1
#  Dona              1
#  Mme               1
#  Sir               1
#  Capt              1
# Name: pre, dtype: int64

# %%
df[df['pre']==' Rev']
# Out:
#       PassengerId  Survived  Pclass                               Name   Sex  \
# 149           150       0.0       2  Byles, Rev. Thomas Roussel Davids  male
# 150           151       0.0       2         Bateman, Rev. Robert James  male
# 249           250       0.0       2      Carter, Rev. Ernest Courtenay  male
# 626           627       0.0       2     Kirkland, Rev. Charles Leonard  male
# 848           849       0.0       2                  Harper, Rev. John  male
# 886           887       0.0       2              Montvila, Rev. Juozas  male
# 1040         1041       NaN       2             Lahtinen, Rev. William  male
# 1055         1056       NaN       2      Peruschitz, Rev. Joseph Maria  male
#
#        Age  SibSp  Parch       Ticket    Fare Cabin Embarked  S     surname  \
# 149   42.0      0      0       244310  13.000   NaN        S  1       Byles
# 150   51.0      0      0  S.O.P. 1166  12.525   NaN        S  1     Bateman
# ...

# %%
df[df['surname']=='Thomas']
# Out:
#       PassengerId  Survived  Pclass  \
# 803           804       1.0       3
# 995           996       NaN       3
# 1007         1008       NaN       3
# 1024         1025       NaN       3
# 1223         1224       NaN       3
#
#                                            Name     Sex    Age  SibSp  Parch  \
# 803             Thomas, Master. Assad Alexander    male   0.42      0      1
# 995   Thomas, Mrs. Alexander (Thamine Thelma")"  female  16.00      1      1
# 1007                           Thomas, Mr. John    male    NaN      0      0
# 1024                      Thomas, Mr. Charles P    male    NaN      1      0
# 1223                        Thomas, Mr. Tannous    male    NaN      0      0
#
#      Ticket    Fare Cabin Embarked  S surname      pre  \
# 803    2625  8.5167   NaN        C  1  Thomas   Master
# 995    2625  8.5167   NaN        C  0  Thomas      Mrs
# 1007   2681  6.4375   NaN        C  0  Thomas       Mr
# 1024   2621  6.4375   NaN        C  0  Thomas       Mr
# ...

# %%
df[df['Cabin']=='D17'] = df[df['Cabin']=='D17'].replace(' Dr',' Mrs')

# %%
df['pre'] = df['pre'].replace(' Col', ' Mr')

# %%
df['pre'] = df['pre'].replace(' Jonkheer', ' Mr')

# %%
df['pre'] = df['pre'].replace(' Lady', ' Mrs')

# %%
df['pre'] = df['pre'].replace(' the Countess', ' Miss')

# %%
df['pre'] = df['pre'].replace(' Dona', ' Miss')

# %%
df['pre'] = df['pre'].replace(' Mme', ' Miss')

# %%
df['pre'] = df['pre'].replace(' Don', ' Mr')

# %%
df['pre'] = df['pre'].replace(' Capt', ' Mr')

# %%
df['pre'] = df['pre'].replace(' Mlle', ' Miss')

# %%
df['pre'] = df['pre'].replace(' Major', ' Mr')

# %%
df['pre'] = df['pre'].replace(' Ms', ' Miss')

# %%
df['pre'] = df['pre'].replace(' Dr', ' Mr')

# %%
df['pre'] = df['pre'].replace(' Rev', ' Mr')

# %%
df['pre'] = df['pre'].replace(' Sir', ' Mr')

# %%
x=df.loc[df['pre']==' Master']['Survived']

# %%
Master_girl = df.loc[(df['pre']==' Mr')&(df['Age']<26)]['Survived']

# %%
Master_girl
# Out:
# 0       0.0
# 12      0.0
# 27      0.0
# 37      0.0
# 51      0.0
#        ...
# 1287    NaN
# 1289    NaN
# 1294    NaN
# 1296    NaN
# 1297    NaN
# Name: Survived, Length: 212, dtype: float64

# %%
df.loc[(df['pre']==' Mr')&(df['Age']<24)]['Survived'].value_counts()
# Out:
# 0.0    99
# 1.0    11
# Name: Survived, dtype: int64

# %%
df['pre'].unique()
# Out:
# array([' Mr', ' Mrs', ' Miss', ' Master'], dtype=object)

# %%
df.drop('Name', inplace=True, axis=1)

# %%
df.isna().sum()
# Out:
# PassengerId       0
# Survived        418
# Pclass            0
# Sex               0
# Age             263
# SibSp             0
# Parch             0
# Ticket            0
# Fare              1
# Cabin          1014
# Embarked          2
# S                 0
# surname           0
# pre               0
# name1             0
# dtype: int64

# %%
df['Embarked'].value_counts()
# Out:
# S    914
# C    270
# Q    123
# Name: Embarked, dtype: int64

# %%
df[df['Embarked']=='Q']
# Out:
#       PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  Ticket  \
# 5               6       0.0       3    male   NaN      0      0  330877
# 16             17       0.0       3    male   2.0      4      1  382652
# 22             23       1.0       3  female  15.0      0      0  330923
# 28             29       1.0       3  female   NaN      0      0  330959
# 32             33       1.0       3  female   NaN      0      0  335677
# ...           ...       ...     ...     ...   ...    ...    ...     ...
# 1287         1288       NaN       3    male  24.0      0      0  371109
# 1290         1291       NaN       3    male  31.0      0      0   21332
# 1299         1300       NaN       3  female   NaN      0      0  334915
# 1301         1302       NaN       3  female   NaN      0      0  365237
# 1302         1303       NaN       1  female  37.0      1      0   19928
#
#          Fare Cabin Embarked  S   surname      pre  \
# ...

# %%
df.loc[547]
# Out:
# PassengerId               548
# Survived                    1
# Pclass                      2
# Sex                      male
# Age                       NaN
# SibSp                       0
# Parch                       0
# Ticket          SC/PARIS 2146
# Fare                  13.8625
# Cabin                     NaN
# Embarked                    C
# S                           1
# surname        Padro y Manent
# pre                        Mr
# name1                  Julian
# Name: 547, dtype: object

# %%
df
# Out:
#       PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  \
# 0               1       0.0       3    male  22.0      1      0
# 1               2       1.0       1  female  38.0      1      0
# 2               3       1.0       3  female  26.0      0      0
# 3               4       1.0       1  female  35.0      1      0
# 4               5       0.0       3    male  35.0      0      0
# ...           ...       ...     ...     ...   ...    ...    ...
# 1304         1305       NaN       3    male   NaN      0      0
# 1305         1306       NaN       1  female  39.0      0      0
# 1306         1307       NaN       3    male  38.5      0      0
# 1307         1308       NaN       3    male   NaN      0      0
# 1308         1309       NaN       3    male   NaN      1      1
#
#                   Ticket      Fare Cabin Embarked  S        surname      pre  \
# 0              A/5 21171    7.2500   NaN        S  1         Braund       Mr
# ...

# %%
df[(df['Pclass']==3)&(df['pre']==' Mrs')&(df['Embarked']=='Q')]['Age'].isna().any()
# Out:
# True

# %%
df[(df['Pclass']==3)&(df['pre']==' Mrs')&(df['Embarked']=='Q')]['Age'].describe()
# Out:
# count     2.000000
# mean     35.500000
# std       4.949747
# min      32.000000
# 25%      33.750000
# 50%      35.500000
# 75%      37.250000
# max      39.000000
# Name: Age, dtype: float64

# %%
df['Embarked'].fillna('C',inplace=True)

# %%
def Input_Age(x):
    Age = x[0]
    Pclass = x[1]
    Sex = x[2]
    pre = x[3]
    Embarked = x[4]
    
    if pd.isna(Age):
        if Pclass == 1:
            if Sex == 'male':
                if pre == ' Mr':
                    if Embarked == 'S':
                         return 42
                    elif Embarked == 'C':
                        return 40
                    else:
                        return Age
                elif pre == ' Master':
                    if Embarked == 'S':
                        return Age
                    elif Embarked == 'C':
                        return Age
                    else:
                        return Age
                else:
                    pass
            
                        
                        
            else:
            
                if pre == ' Miss':
                    if Embarked == 'S':
                        return Age
                    elif Embarked == 'C':
                        return 32
                    else:
                        return Age
                elif pre==' Mrs':
                    if Embarked == 'S':
                        return 45
                    elif Embarked == 'C':
                        return 48
                    else:
                        return Age
                else:
                        pass
                
                        
        if Pclass == 2:
            if Sex == 'male':
                if pre == ' Mr':
                    if Embarked == 'S':
                        return 30
                    elif Embarked == 'C':
                        return 30
                    else:
                        return 59
                elif pre == ' Master':
                    if Embarked == 'S':
                        return Age
                    elif Embarked == 'C':
                        return Age
                    else:
                        return Age
                else:
                    pass
                
                        
            else:
                
                if pre == ' Miss':
                    if Embarked == 'S':
                        return 20
                    elif Embarked == 'C':
                        return Age
                    else:
                        return 30
                elif pre == ' Mrs':
                    if Embarked == 'S':
                        return 32.5
                    elif Embarked == 'C':
                        return Age
                    else:
                        return Age

                        
        if Pclass == 3:
            if Sex == 'male':
            
                if pre == ' Mr':
                    if Embarked == 'S':
                        return 26
                    elif Embarked == 'C':
                        return 25.5
                    else:
                        return 30
                elif pre == ' Master':
                    if Embarked == 'S':
                        return 5.5
                    elif Embarked == 'C':
                        return 6.5
                    else:
                        return Age
                else:
                    pass
                
                        
                        
            else:
                
                    if pre == ' Miss':
                        if Embarked == 'S':
                            return 20
                        elif Embarked == 'C':
                            return 9
                        else:
                            return 22
                    elif pre == ' Mrs':
                        if Embarked == 'S':
                            return 31
                        elif Embarked == 'C':
                            return 24
                        else:
                            return 35.5
                    else:
                        pass
                
    
    else:
        return Age

# %%
df[(df['Pclass']==3)&(df['Sex']=='female')&(df['Survived']==0)&(df['pre']==' Mrs')&(df['Embarked']=='C')]['Age'].describe()
# Out:
# count     1.0
# mean     45.0
# std       NaN
# min      45.0
# 25%      45.0
# 50%      45.0
# 75%      45.0
# max      45.0
# Name: Age, dtype: float64

# %%
df['Age']= df[['Age','Pclass', 'Sex','pre','Embarked']].apply(Input_Age, axis=1)

# %%
df.isna().sum()
# Out:
# PassengerId       0
# Survived        418
# Pclass            0
# Sex               0
# Age               0
# SibSp             0
# Parch             0
# Ticket            0
# Fare              1
# Cabin          1014
# Embarked          0
# S                 0
# surname           0
# pre               0
# name1             0
# dtype: int64

# %%
df[df['Age'].isna()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked, S, surname, pre, name1]
# Index: []

# %%
df[df['pre']=='Master']['Age']
# Out:
# Series([], Name: Age, dtype: float64)

# %%
df[(df['Sex']=='male')&(df['Embarked']=='C')&(df['pre']==' Master')]['Age'].median()
# Out:
# 6.5

# %%
df
# Out:
#       PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  \
# 0               1       0.0       3    male  22.0      1      0
# 1               2       1.0       1  female  38.0      1      0
# 2               3       1.0       3  female  26.0      0      0
# 3               4       1.0       1  female  35.0      1      0
# 4               5       0.0       3    male  35.0      0      0
# ...           ...       ...     ...     ...   ...    ...    ...
# 1304         1305       NaN       3    male  26.0      0      0
# 1305         1306       NaN       1  female  39.0      0      0
# 1306         1307       NaN       3    male  38.5      0      0
# 1307         1308       NaN       3    male  26.0      0      0
# 1308         1309       NaN       3    male   6.5      1      1
#
#                   Ticket      Fare Cabin Embarked  S        surname      pre  \
# 0              A/5 21171    7.2500   NaN        S  1         Braund       Mr
# ...

# %%
pd.set_option('display.max_row',22)

# %%
pd.options.display.max_rows
# Out:
# 22

# %%
df['Fare'].fillna(25, inplace=True)

# %%
df.drop(['Ticket', 'Cabin','surname','name1','PassengerId'], axis=1, inplace=True)

# %%
dummy = pd.get_dummies(df[['Sex','Embarked','pre']], drop_first=True)

# %%
df_new = pd.concat([df,dummy], axis = 1)

# %%
df_new
# Out:
#       Survived  Pclass     Sex   Age  SibSp  Parch      Fare Embarked  S  \
# 0          0.0       3    male  22.0      1      0    7.2500        S  1
# 1          1.0       1  female  38.0      1      0   71.2833        C  1
# 2          1.0       3  female  26.0      0      0    7.9250        S  1
# 3          1.0       1  female  35.0      1      0   53.1000        S  1
# 4          0.0       3    male  35.0      0      0    8.0500        S  1
# ...        ...     ...     ...   ...    ...    ...       ...      ... ..
# 1304       NaN       3    male  26.0      0      0    8.0500        S  0
# 1305       NaN       1  female  39.0      0      0  108.9000        C  0
# 1306       NaN       3    male  38.5      0      0    7.2500        S  0
# 1307       NaN       3    male  26.0      0      0    8.0500        S  0
# 1308       NaN       3    male   6.5      1      1   22.3583        C  0
#
#           pre  Sex_male  Embarked_Q  Embarked_S  pre_ Miss  pre_ Mr  pre_ Mrs
# ...

# %%
df_new.describe()
# Out:
#          Survived       Pclass          Age        SibSp        Parch  \
# count  891.000000  1309.000000  1309.000000  1309.000000  1309.000000
# mean     0.383838     2.294882    29.478739     0.498854     0.385027
# std      0.486592     0.837836    13.405408     1.041658     0.865560
# min      0.000000     1.000000     0.170000     0.000000     0.000000
# 25%      0.000000     2.000000    22.000000     0.000000     0.000000
# 50%      0.000000     3.000000    27.000000     0.000000     0.000000
# 75%      1.000000     3.000000    37.000000     1.000000     0.000000
# max      1.000000     3.000000    80.000000     8.000000     9.000000
#
#               Fare            S     Sex_male   Embarked_Q   Embarked_S  \
# count  1309.000000  1309.000000  1309.000000  1309.000000  1309.000000
# mean     33.289142     0.680672     0.644003     0.093965     0.698243
# std      51.739387     0.466394     0.478997     0.291891     0.459196
# ...

# %%
df_new.drop(['Sex','Embarked','pre'], axis=1, inplace=True)

# %%
from sklearn.preprocessing import StandardScaler

# %%
XX = df_new[df_new['S']==1]

# %%
X = XX.drop('Survived', axis=1)

# %%
y=XX['Survived']

# %%
real_test_data = df_new[df_new['S']==0]

# %%
real_test_data= real_test_data.drop('Survived',axis=1)

# %%
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier

# %%
from sklearn.model_selection import RandomizedSearchCV
from xgboost import XGBClassifier

# %%
rf = RandomForestClassifier()

# %%
rf.fit(X,y)
# Out:
# RandomForestClassifier()

# %%
n_estimators = [int(x) for x in np.linspace(start = 100, stop = 1000, num = 10)]
max_features = ['auto', 'sqrt']
max_depth = [int(x) for x in np.linspace(10, 90,9)]

# %%
random_grid = {'n_estimators':n_estimators,
               'max_features':max_features,
               'max_depth':max_depth
              }

# %%
random_cv = RandomizedSearchCV(rf,random_grid,n_iter=100,cv=5,verbose=2, random_state=69, n_jobs = -1)

# %%
random_cv.fit(X,y)
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:   22.5s
# [Parallel(n_jobs=-1)]: Done 154 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=-1)]: Done 357 tasks      | elapsed:  4.1min
# [Parallel(n_jobs=-1)]: Done 500 out of 500 | elapsed:  5.6min finished
# RandomizedSearchCV(cv=5, estimator=RandomForestClassifier(), n_iter=100,
#                    n_jobs=-1,
#                    param_distributions={'max_depth': [10, 20, 30, 40, 50, 60,
#                                                       70, 80, 90],
#                                         'max_features': ['auto', 'sqrt'],
#                                         'n_estimators': [100, 200, 300, 400,
#                                                          500, 600, 700, 800,
#                                                          900, 1000]},
# ...

# %%
random_cv.best_estimator_
# Out:
# RandomForestClassifier(max_depth=10, max_features='sqrt', n_estimators=1000)

# %%
from xgboost import XGBClassifier

# %%
xgb = XGBClassifier()

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.25,random_state=69)

# %%
xgb.fit(X_train,y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#               importance_type='gain', interaction_constraints='',
#               learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#               min_child_weight=1, missing=nan, monotone_constraints='()',
#               n_estimators=100, n_jobs=0, num_parallel_tree=1, random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#               tree_method='exact', validate_parameters=1, verbosity=None)

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import RandomizedSearchCV

# %%
rf_final = RandomForestClassifier(max_depth=10, max_features='sqrt', n_estimators=1000)

# %%
rf_final.fit(X_train,y_train)
# Out:
# RandomForestClassifier(max_depth=10, max_features='sqrt', n_estimators=1000)

# %%
rf_y_pred = rf_final.predict(X_test)

# %%
y_pred_xgb = xgb.predict(X_test)

# %%
confusion_matrix(y_test,y_pred_xgb)
# Out:
# array([[120,  20],
#        [ 21,  62]])

# %%
mean_squared_error(y_test,y_pred_xgb)

# %%
confusion_matrix(y_test,rf_y_pred)
# Out:
# array([[128,  12],
#        [ 24,  59]])

# %%
mean_squared_error(y_test,rf_y_pred)
# Out:
# 0.16143497757847533

# %%
eval_set = [(X_train, y_train), (X_test, y_test)]
eval_metric = ["auc","error"]

# %%
params={'n_estimators':[100,300,500,700,1000],
        'max_depth':[3,4,5,6],
        'learning_rate':[0.01,0.5,0.1],
       }

# %%
random_xgb = RandomizedSearchCV(xgb,params,cv=3,random_state=2,n_iter=40)

# %%
random_xgb.fit(X, y)
# Out:
# RandomizedSearchCV(cv=3,
#                    estimator=XGBClassifier(base_score=0.5, booster='gbtree',
#                                            colsample_bylevel=1,
#                                            colsample_bynode=1,
#                                            colsample_bytree=1, gamma=0,
#                                            gpu_id=-1, importance_type='gain',
#                                            interaction_constraints='',
#                                            learning_rate=0.300000012,
#                                            max_delta_step=0, max_depth=6,
#                                            min_child_weight=1, missing=nan,
#                                            monotone_constraints='()',
#                                            n_estimators=100, n_jobs=0,
#                                            num_parallel_tree=1, random_state=0,
#                                            reg_alpha=0, reg_lambda=1,
# ...

# %%
random_xgb.best_estimator_
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#               importance_type='gain', interaction_constraints='',
#               learning_rate=0.01, max_delta_step=0, max_depth=3,
#               min_child_weight=1, missing=nan, monotone_constraints='()',
#               n_estimators=300, n_jobs=0, num_parallel_tree=1, random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#               tree_method='exact', validate_parameters=1, verbosity=None)

# %%
random_cv.best_estimator_
# Out:
# RandomForestClassifier(max_depth=10, n_estimators=600)

# %%
y_rand_xgb = random_xgb.predict(X_test)

# %%
random_xgb.best_score_
# Out:
# 0.8248629795714998

# %%
random_cv.best_score_
# Out:
# 0.8368757715183481

# %%
confusion_matrix(y_test,y_rand_xgb)
# Out:
# array([[130,  10],
#        [ 20,  63]])

# %%
y_rand_rf = random_cv.predict(X_test)

# %%
confusion_matrix(y_test,y_rand_rf)
# Out:
# array([[126,  14],
#        [ 23,  60]])

# %%
result = random_xgb.predict(real_test_data)

# %%
result = result.astype(int)

# %%
submission = pd.DataFrame({
    'PassengerId':test['PassengerId'],
    'Survived':result
})

# %%
submission.to_csv('try7_HPT_XGB.csv', index=False)
